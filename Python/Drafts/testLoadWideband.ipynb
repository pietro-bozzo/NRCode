# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import fmatoolbox as fma
batch_file = '/mnt/hubel-data-103/Pietro/InfraSlowNRPaper/Data/IS_intervals.batch'

# %%
session = fma.data.readBatchFile(batch_file)[0][25]
print(session)
# Out:
# /mnt/hubel-data-140/karadoc/Rat004_20240314/Rat004_20240314.xml

# %%
fma.data.printXML(session)
# Out:
# parameters {'version': '1.0', 'creator': 'ndManager-'}
#   generalInfo
#     date -> 2023-08-02
#     experimenters -> paularno
#     description
#     notes
#   acquisitionSystem
#     nBits -> 16
#     nChannels -> 142
#     samplingRate -> 20000
#     voltageRange -> 20
#     amplification -> 1000
#     offset -> 0
#   fieldPotentials
#     lfpSamplingRate -> 1250
#   files
#     file
#       extension -> lfp
#       samplingRate -> 1250
#   anatomicalDescription
#     channelGroups
#       group
#         channel {'skip': '0'} -> 51
#         channel {'skip': '0'} -> 52
#         channel {'skip': '0'} -> 53
#         channel {'skip': '0'} -> 54
#         channel {'skip': '0'} -> 50
#         channel {'skip': '0'} -> 55
#         channel {'skip': '0'} -> 56
#         channel {'skip': '0'} -> 57
#         channel {'skip': '0'} -> 49
#         channel {'skip': '0'} -> 58
#         channel {'skip': '0'} -> 59
#         channel {'skip': '0'} -> 60
# ...

# %%
A, t = fma.data.loadWideband(session,intervals=[[0,100],[100,200]])

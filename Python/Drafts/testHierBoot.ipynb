# %%
import numpy as np
import fmatoolbox as fma

# %%
a = np.sort(np.random.default_rng().choice(15,7,replace=False))
b = np.sort(np.random.default_rng().choice(25,7,replace=False)) + 3
fma.statistics.hierarchicalBootsrap(a, [0,0,0,0,1,1,1], b, [0,1,2,0,1,2,0] )
# Out:
# (array([[11.33333333],
#         [ 7.        ],
#         [ 2.875     ],
#         [ 4.        ],
#         [ 2.875     ],
#         [ 5.125     ],
#         [11.33333333],
#         [11.66666667],
#         [ 8.57142857],
#         [ 4.875     ],
#         [11.66666667],
#         [ 7.42857143],
#         [ 8.        ],
#         [ 7.71428571],
#         [ 5.        ],
#         [ 4.625     ],
#         [ 8.28571429],
#         [10.66666667],
#         [ 2.875     ],
#         [ 3.625     ],
#         [12.        ],
#         [11.83333333],
#         [11.16666667],
#         [ 8.28571429],
#         [ 5.625     ],
#         [12.        ],
#         [ 7.57142857],
#         [ 5.625     ],
#         [ 8.14285714],
#         [ 8.71428571],
#         [ 8.85714286],
#         [ 6.71428571],
#         [ 7.57142857],
#         [ 8.14285714],
#         [ 3.75      ],
#         [12.        ],
#         [11.16666667],
#         [ 3.75      ],
#         [11.83333333],
#         [ 4.25      ],
# ...

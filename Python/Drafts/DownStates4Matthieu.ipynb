# %%
import fmatoolbox

# %%
import fmatoolbox
# spikes should be a 1d array with all spike times from cortex neurons (disregarding neuron id)
fr = fmatoolbox.analysis.firingRate(spikes,bin_size=0.01)
threshold = 10
size, intervals, _ = fmatoolbox.analysis.avalanchesFromProfile(fr[:,1],threshold,time_step=fr[1,0]-fr[0,0],t0=fr[0,0])

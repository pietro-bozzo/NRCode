# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import fmatoolbox as fma
import regions as rg
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# parameters
regs = ['hpc','nr','pfc']
batch_file = '/mnt/hubel-data-103/Pietro/InfraSlowNRPaper/Data/IS_units.batch'
session = fma.data.readBatchFile(batch_file)[0][19]
print(f'session: {session}')
# Out:
# session: /mnt/hubel-data-140/karadoc/Rat004_20240306/Rat004_20240306.xml

# %%
R = rg.data.Regions(session,ids=['pfc','nr'],states='sws',events=['InfraSlowRhythm/slownr','InfraSlowRhythm/slowavalnr','ripples'])
